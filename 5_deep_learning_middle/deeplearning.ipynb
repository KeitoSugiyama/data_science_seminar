# %% [markdown]
# # パラメータ最適化の各手法比較
# ## 収束までの道のり

# %%
import sys, os
sys.path.append(os.pardir)  # 親ディレクトリのファイルをインポートするための設定
import numpy as np
import matplotlib.pyplot as plt
from collections import OrderedDict
from common.optimizer import *


def f(x, y):
    return x**2 / 20.0 + y**2


def df(x, y):
    return x / 10.0, 2.0*y

init_pos = (-7.0, 2.0)
params = {}
params['x'], params['y'] = init_pos[0], init_pos[1]
grads = {}
grads['x'], grads['y'] = 0, 0


optimizers = OrderedDict()
optimizers["SGD"] = SGD(lr=0.95)
optimizers["Momentum"] = Momentum(lr=0.1)
optimizers["AdaGrad"] = AdaGrad(lr=1.5)
optimizers["Adam"] = Adam(lr=0.3)

idx = 1

for key in optimizers:
    optimizer = optimizers[key]
    x_history = []
    y_history = []
    params['x'], params['y'] = init_pos[0], init_pos[1]
    
    for i in range(30):
        x_history.append(params['x'])
        y_history.append(params['y'])
        
        grads['x'], grads['y'] = df(params['x'], params['y'])
        optimizer.update(params, grads)
    

    x = np.arange(-10, 10, 0.01)
    y = np.arange(-5, 5, 0.01)
    
    X, Y = np.meshgrid(x, y) 
    Z = f(X, Y)
    
    # for simple contour line  
    mask = Z > 7
    Z[mask] = 0
    
    # plot 
    plt.subplot(2, 2, idx)
    idx += 1
    plt.plot(x_history, y_history, 'o-', color="red")
    plt.contour(X, Y, Z)
    plt.ylim(-10, 10)
    plt.xlim(-10, 10)
    plt.plot(0, 0, '+')
    #colorbar()
    #spring()
    plt.title(key)
    plt.xlabel("x")
    plt.ylabel("y")
    
plt.show()

# %% [markdown]
# ## 各手法の誤差の大きさ

# %%
# coding: utf-8
import os
import sys
sys.path.append(os.pardir)  # 親ディレクトリのファイルをインポートするための設定
import matplotlib.pyplot as plt
from dataset.mnist import load_mnist
from common.util import smooth_curve
from common.multi_layer_net import MultiLayerNet
from common.optimizer import *


# 0:MNISTデータの読み込み==========
(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

train_size = x_train.shape[0]
batch_size = 128
max_iterations = 2000


# 1:実験の設定==========
optimizers = {}
optimizers['SGD'] = SGD()
optimizers['Momentum'] = Momentum()
optimizers['AdaGrad'] = AdaGrad()
optimizers['Adam'] = Adam()
#optimizers['RMSprop'] = RMSprop()

networks = {}
train_loss = {}
for key in optimizers.keys():
    networks[key] = MultiLayerNet(
        input_size=784, hidden_size_list=[100, 100, 100, 100],
        output_size=10)
    train_loss[key] = []    


# 2:訓練の開始==========
for i in range(max_iterations):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    t_batch = t_train[batch_mask]
    
    for key in optimizers.keys():
        grads = networks[key].gradient(x_batch, t_batch)
        optimizers[key].update(networks[key].params, grads)
    
        loss = networks[key].loss(x_batch, t_batch)
        train_loss[key].append(loss)
    
    if i % 100 == 0:
        #print( "===========" + "iteration:" + str(i) + "===========")
        for key in optimizers.keys():
            loss = networks[key].loss(x_batch, t_batch)
            #print(key + ":" + str(loss))


# 3.グラフの描画==========
markers = {"SGD": "o", "Momentum": "x", "AdaGrad": "s", "Adam": "D"}
x = np.arange(max_iterations)
for key in optimizers.keys():
    plt.plot(x, smooth_curve(train_loss[key]), marker=markers[key], markevery=100, label=key)
plt.xlabel("iterations")
plt.ylabel("loss")
plt.ylim(0, 1)
plt.legend()
plt.show()

# %% [markdown]
# # 重みの初期化の手法

# %%
import numpy as np
import matplotlib.pyplot as plt


def sigmoid(x):
    return 1 / (1 + np.exp(-x))


def ReLU(x):
    return np.maximum(0, x)


def tanh(x):
    return np.tanh(x)
    
input_data = np.random.randn(1000, 100)  # 1000個のデータ
node_num = 100  # 各隠れ層のノード（ニューロン）の数
hidden_layer_size = 5  # 隠れ層が5層
activations = {}  # ここにアクティベーションの結果を格納する

x = input_data

for i in range(hidden_layer_size):
    if i != 0:
        x = activations[i-1]

    # 初期値の値をいろいろ変えて実験しよう！
    #w = np.random.randn(node_num, node_num) * 1
    #w = np.random.randn(node_num, node_num) * 0.01
    #w = np.random.randn(node_num, node_num) * np.sqrt(1.0 / node_num) #Xabir
    w = np.random.randn(node_num, node_num) * np.sqrt(2.0 / node_num) #He


    a = np.dot(x, w)


    # 活性化関数の種類も変えて実験しよう！
    #z = sigmoid(a)
    #z = ReLU(a)
    #z = tanh(a)

    activations[i] = z

# ヒストグラムを描画
for i, a in activations.items():
    plt.subplot(1, len(activations), i+1)
    plt.title(str(i+1) + "-layer")
    if i != 0: plt.yticks([], [])
    # plt.xlim(0.1, 1)
    # plt.ylim(0, 7000)
    plt.hist(a.flatten(), 30, range=(0,1))
plt.show()

# %%
# coding: utf-8
import os
import sys

sys.path.append(os.pardir)  # 親ディレクトリのファイルをインポートするための設定
import numpy as np
import matplotlib.pyplot as plt
from dataset.mnist import load_mnist
from common.util import smooth_curve
from common.multi_layer_net import MultiLayerNet
from common.optimizer import SGD


# 0:MNISTデータの読み込み==========
(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

train_size = x_train.shape[0]
batch_size = 128
max_iterations = 2000


# 1:実験の設定==========
weight_init_types = {'std=0.01': 0.01, 'Xavier': 'sigmoid', 'He': 'relu'}
optimizer = SGD(lr=0.01)

networks = {}
train_loss = {}
for key, weight_type in weight_init_types.items():
    networks[key] = MultiLayerNet(input_size=784, hidden_size_list=[100, 100, 100, 100],
                                  output_size=10, weight_init_std=weight_type)
    train_loss[key] = []


# 2:訓練の開始==========
for i in range(max_iterations):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    t_batch = t_train[batch_mask]
    
    for key in weight_init_types.keys():
        grads = networks[key].gradient(x_batch, t_batch)
        optimizer.update(networks[key].params, grads)
    
        loss = networks[key].loss(x_batch, t_batch)
        train_loss[key].append(loss)
    
    if i % 100 == 0:
        #print("===========" + "iteration:" + str(i) + "===========")
        for key in weight_init_types.keys():
            loss = networks[key].loss(x_batch, t_batch)
            #print(key + ":" + str(loss))


# 3.グラフの描画==========
markers = {'std=0.01': 'o', 'Xavier': 's', 'He': 'D'}
x = np.arange(max_iterations)
for key in weight_init_types.keys():
    plt.plot(x, smooth_curve(train_loss[key]), marker=markers[key], markevery=100, label=key)
plt.xlabel("iterations")
plt.ylabel("loss")
plt.ylim(0, 2.5)
plt.legend()
plt.show()

# %% [markdown]
# # 過学習の抑制
# ## Weight decayを使う場合

# %%
# coding: utf-8
import os
import sys

sys.path.append(os.pardir)  # 親ディレクトリのファイルをインポートするための設定
import numpy as np
import matplotlib.pyplot as plt
from dataset.mnist import load_mnist
from common.multi_layer_net import MultiLayerNet
from common.optimizer import SGD

(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

# 過学習を再現するために、学習データを削減
x_train = x_train[:300]
t_train = t_train[:300]

# weight decay（荷重減衰）の設定 =======================
#weight_decay_lambda = 0 # weight decayを使用しない場合
weight_decay_lambda = 0.1
# ====================================================

network = MultiLayerNet(input_size=784, hidden_size_list=[100, 100, 100, 100, 100, 100], output_size=10,
                        weight_decay_lambda=weight_decay_lambda)
optimizer = SGD(lr=0.01)

max_epochs = 201
train_size = x_train.shape[0]
batch_size = 100

train_loss_list = []
train_acc_list = []
test_acc_list = []

iter_per_epoch = max(train_size / batch_size, 1)
epoch_cnt = 0

for i in range(1000000000):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    t_batch = t_train[batch_mask]

    grads = network.gradient(x_batch, t_batch)
    optimizer.update(network.params, grads)

    if i % iter_per_epoch == 0:
        train_acc = network.accuracy(x_train, t_train)
        test_acc = network.accuracy(x_test, t_test)
        train_acc_list.append(train_acc)
        test_acc_list.append(test_acc)

        print("epoch:" + str(epoch_cnt) + ", train acc:" + str(train_acc) + ", test acc:" + str(test_acc))

        epoch_cnt += 1
        if epoch_cnt >= max_epochs:
            break


# 3.グラフの描画==========
markers = {'train': 'o', 'test': 's'}
x = np.arange(max_epochs)
plt.plot(x, train_acc_list, marker='o', label='train', markevery=10)
plt.plot(x, test_acc_list, marker='s', label='test', markevery=10)
plt.xlabel("epochs")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
plt.legend(loc='lower right')
plt.show()
# Out:
# epoch:0, train acc:0.126666666667, test acc:0.1096
# epoch:1, train acc:0.13, test acc:0.1192
# epoch:2, train acc:0.133333333333, test acc:0.1234
# epoch:3, train acc:0.183333333333, test acc:0.1463
# epoch:4, train acc:0.2, test acc:0.1617
# epoch:5, train acc:0.216666666667, test acc:0.1741
# epoch:6, train acc:0.216666666667, test acc:0.1804
# epoch:7, train acc:0.236666666667, test acc:0.1858
# epoch:8, train acc:0.243333333333, test acc:0.1919
# epoch:9, train acc:0.246666666667, test acc:0.1972
# epoch:10, train acc:0.293333333333, test acc:0.2136
# epoch:11, train acc:0.293333333333, test acc:0.2231
# epoch:12, train acc:0.303333333333, test acc:0.2294
# epoch:13, train acc:0.33, test acc:0.2355
# epoch:14, train acc:0.35, test acc:0.2462
# epoch:15, train acc:0.353333333333, test acc:0.2574
# epoch:16, train acc:0.35, test acc:0.2684
# epoch:17, train acc:0.403333333333, test acc:0.2977
# epoch:18, train acc:0.426666666667, test acc:0.3068
# epoch:19, train acc:0.436666666667, test acc:0.3237
# epoch:20, train acc:0.46, test acc:0.3347
# epoch:21, train acc:0.456666666667, test acc:0.336
# epoch:22, train acc:0.47, test acc:0.3508
# epoch:23, train acc:0.493333333333, test acc:0.3674
# epoch:24, train acc:0.496666666667, test acc:0.3741
# epoch:25, train acc:0.553333333333, test acc:0.4043
# epoch:26, train acc:0.55, test acc:0.4028
# epoch:27, train acc:0.58, test acc:0.4198
# epoch:28, train acc:0.58, test acc:0.4204
# epoch:29, train acc:0.57, test acc:0.4266
# epoch:30, train acc:0.59, test acc:0.4347
# epoch:31, train acc:0.596666666667, test acc:0.4424
# epoch:32, train acc:0.606666666667, test acc:0.4609
# epoch:33, train acc:0.613333333333, test acc:0.4517
# epoch:34, train acc:0.616666666667, test acc:0.4765
# epoch:35, train acc:0.623333333333, test acc:0.485
# epoch:36, train acc:0.643333333333, test acc:0.5002
# epoch:37, train acc:0.666666666667, test acc:0.5091
# epoch:38, train acc:0.653333333333, test acc:0.5013
# epoch:39, train acc:0.63, test acc:0.4923
# epoch:40, train acc:0.67, test acc:0.5179
# epoch:41, train acc:0.66, test acc:0.5247
# epoch:42, train acc:0.666666666667, test acc:0.5279
# epoch:43, train acc:0.67, test acc:0.53
# epoch:44, train acc:0.713333333333, test acc:0.5483
# epoch:45, train acc:0.726666666667, test acc:0.5712
# epoch:46, train acc:0.733333333333, test acc:0.5793
# epoch:47, train acc:0.74, test acc:0.5792
# epoch:48, train acc:0.736666666667, test acc:0.583
# epoch:49, train acc:0.75, test acc:0.5711
# epoch:50, train acc:0.74, test acc:0.5782
# epoch:51, train acc:0.753333333333, test acc:0.5985
# epoch:52, train acc:0.756666666667, test acc:0.591
# epoch:53, train acc:0.753333333333, test acc:0.5963
# epoch:54, train acc:0.77, test acc:0.6004
# epoch:55, train acc:0.763333333333, test acc:0.6075
# epoch:56, train acc:0.756666666667, test acc:0.6085
# epoch:57, train acc:0.786666666667, test acc:0.605
# epoch:58, train acc:0.783333333333, test acc:0.6133
# epoch:59, train acc:0.813333333333, test acc:0.625
# epoch:60, train acc:0.793333333333, test acc:0.6266
# epoch:61, train acc:0.81, test acc:0.6314
# epoch:62, train acc:0.813333333333, test acc:0.6271
# epoch:63, train acc:0.8, test acc:0.6247
# epoch:64, train acc:0.8, test acc:0.6213
# epoch:65, train acc:0.79, test acc:0.6238
# epoch:66, train acc:0.803333333333, test acc:0.6299
# epoch:67, train acc:0.813333333333, test acc:0.6377
# epoch:68, train acc:0.82, test acc:0.6411
# epoch:69, train acc:0.81, test acc:0.6307
# epoch:70, train acc:0.82, test acc:0.6397
# epoch:71, train acc:0.816666666667, test acc:0.6423
# epoch:72, train acc:0.82, test acc:0.6494
# epoch:73, train acc:0.823333333333, test acc:0.6518
# epoch:74, train acc:0.833333333333, test acc:0.6582
# epoch:75, train acc:0.816666666667, test acc:0.6498
# epoch:76, train acc:0.826666666667, test acc:0.6552
# epoch:77, train acc:0.85, test acc:0.6668
# epoch:78, train acc:0.83, test acc:0.6478
# epoch:79, train acc:0.83, test acc:0.6489
# epoch:80, train acc:0.823333333333, test acc:0.6485
# epoch:81, train acc:0.843333333333, test acc:0.6554
# epoch:82, train acc:0.816666666667, test acc:0.6499
# epoch:83, train acc:0.83, test acc:0.664
# epoch:84, train acc:0.84, test acc:0.6524
# epoch:85, train acc:0.806666666667, test acc:0.6404
# epoch:86, train acc:0.823333333333, test acc:0.6606
# epoch:87, train acc:0.833333333333, test acc:0.6715
# epoch:88, train acc:0.833333333333, test acc:0.659
# epoch:89, train acc:0.836666666667, test acc:0.6634
# epoch:90, train acc:0.83, test acc:0.6533
# epoch:91, train acc:0.84, test acc:0.6638
# epoch:92, train acc:0.85, test acc:0.6619
# epoch:93, train acc:0.84, test acc:0.6627
# epoch:94, train acc:0.846666666667, test acc:0.6602
# epoch:95, train acc:0.853333333333, test acc:0.6794
# epoch:96, train acc:0.843333333333, test acc:0.6643
# epoch:97, train acc:0.843333333333, test acc:0.6651
# epoch:98, train acc:0.85, test acc:0.6726
# epoch:99, train acc:0.853333333333, test acc:0.6716
# epoch:100, train acc:0.863333333333, test acc:0.6845
# epoch:101, train acc:0.85, test acc:0.6935
# epoch:102, train acc:0.85, test acc:0.6796
# epoch:103, train acc:0.85, test acc:0.6813
# epoch:104, train acc:0.876666666667, test acc:0.6898
# epoch:105, train acc:0.85, test acc:0.6847
# epoch:106, train acc:0.87, test acc:0.693
# epoch:107, train acc:0.843333333333, test acc:0.6886
# epoch:108, train acc:0.88, test acc:0.6945
# epoch:109, train acc:0.866666666667, test acc:0.6961
# epoch:110, train acc:0.866666666667, test acc:0.6947
# epoch:111, train acc:0.866666666667, test acc:0.6791
# epoch:112, train acc:0.88, test acc:0.6949
# epoch:113, train acc:0.863333333333, test acc:0.6782
# epoch:114, train acc:0.856666666667, test acc:0.6913
# epoch:115, train acc:0.856666666667, test acc:0.6878
# epoch:116, train acc:0.89, test acc:0.6959
# epoch:117, train acc:0.873333333333, test acc:0.692
# epoch:118, train acc:0.88, test acc:0.6916
# epoch:119, train acc:0.886666666667, test acc:0.6919
# epoch:120, train acc:0.866666666667, test acc:0.6889
# epoch:121, train acc:0.866666666667, test acc:0.6873
# epoch:122, train acc:0.873333333333, test acc:0.6977
# epoch:123, train acc:0.846666666667, test acc:0.6716
# epoch:124, train acc:0.876666666667, test acc:0.6983
# epoch:125, train acc:0.88, test acc:0.6966
# epoch:126, train acc:0.883333333333, test acc:0.6966
# epoch:127, train acc:0.87, test acc:0.6951
# epoch:128, train acc:0.88, test acc:0.6925
# epoch:129, train acc:0.866666666667, test acc:0.6914
# epoch:130, train acc:0.873333333333, test acc:0.6849
# epoch:131, train acc:0.863333333333, test acc:0.6868
# epoch:132, train acc:0.88, test acc:0.6938
# epoch:133, train acc:0.883333333333, test acc:0.6997
# epoch:134, train acc:0.88, test acc:0.7012
# epoch:135, train acc:0.886666666667, test acc:0.7029
# epoch:136, train acc:0.866666666667, test acc:0.6916
# epoch:137, train acc:0.886666666667, test acc:0.7031
# epoch:138, train acc:0.87, test acc:0.6956
# epoch:139, train acc:0.883333333333, test acc:0.7095
# epoch:140, train acc:0.873333333333, test acc:0.6963
# epoch:141, train acc:0.88, test acc:0.705
# epoch:142, train acc:0.89, test acc:0.6992
# epoch:143, train acc:0.88, test acc:0.6915
# epoch:144, train acc:0.876666666667, test acc:0.7018
# epoch:145, train acc:0.886666666667, test acc:0.6909
# epoch:146, train acc:0.88, test acc:0.7027
# epoch:147, train acc:0.89, test acc:0.7087
# epoch:148, train acc:0.89, test acc:0.7062
# epoch:149, train acc:0.893333333333, test acc:0.7019
# epoch:150, train acc:0.883333333333, test acc:0.7027
# epoch:151, train acc:0.883333333333, test acc:0.6991
# epoch:152, train acc:0.893333333333, test acc:0.705
# epoch:153, train acc:0.873333333333, test acc:0.6986
# epoch:154, train acc:0.876666666667, test acc:0.701
# epoch:155, train acc:0.896666666667, test acc:0.7088
# epoch:156, train acc:0.89, test acc:0.702
# epoch:157, train acc:0.893333333333, test acc:0.7042
# epoch:158, train acc:0.886666666667, test acc:0.7013
# epoch:159, train acc:0.883333333333, test acc:0.7107
# epoch:160, train acc:0.886666666667, test acc:0.7106
# epoch:161, train acc:0.9, test acc:0.7123
# epoch:162, train acc:0.896666666667, test acc:0.7127
# epoch:163, train acc:0.88, test acc:0.706
# epoch:164, train acc:0.903333333333, test acc:0.7145
# epoch:165, train acc:0.893333333333, test acc:0.7031
# epoch:166, train acc:0.903333333333, test acc:0.7067
# epoch:167, train acc:0.866666666667, test acc:0.7007
# epoch:168, train acc:0.903333333333, test acc:0.7084
# epoch:169, train acc:0.893333333333, test acc:0.7065
# epoch:170, train acc:0.886666666667, test acc:0.7055
# epoch:171, train acc:0.906666666667, test acc:0.7105
# epoch:172, train acc:0.9, test acc:0.7154
# epoch:173, train acc:0.896666666667, test acc:0.7107
# epoch:174, train acc:0.893333333333, test acc:0.709
# epoch:175, train acc:0.893333333333, test acc:0.7086
# epoch:176, train acc:0.893333333333, test acc:0.7113
# epoch:177, train acc:0.906666666667, test acc:0.7105
# epoch:178, train acc:0.9, test acc:0.7069
# epoch:179, train acc:0.896666666667, test acc:0.7119
# epoch:180, train acc:0.9, test acc:0.7039
# epoch:181, train acc:0.89, test acc:0.711
# epoch:182, train acc:0.9, test acc:0.7088
# epoch:183, train acc:0.9, test acc:0.7089
# epoch:184, train acc:0.896666666667, test acc:0.7043
# epoch:185, train acc:0.896666666667, test acc:0.7071
# epoch:186, train acc:0.893333333333, test acc:0.7068
# epoch:187, train acc:0.88, test acc:0.7013
# epoch:188, train acc:0.883333333333, test acc:0.7025
# epoch:189, train acc:0.9, test acc:0.7038
# epoch:190, train acc:0.903333333333, test acc:0.7108
# epoch:191, train acc:0.896666666667, test acc:0.7055
# epoch:192, train acc:0.903333333333, test acc:0.7063
# epoch:193, train acc:0.886666666667, test acc:0.7078
# epoch:194, train acc:0.896666666667, test acc:0.7111
# epoch:195, train acc:0.886666666667, test acc:0.7079
# epoch:196, train acc:0.893333333333, test acc:0.7107
# epoch:197, train acc:0.893333333333, test acc:0.7099
# epoch:198, train acc:0.886666666667, test acc:0.7052
# epoch:199, train acc:0.903333333333, test acc:0.7149
# epoch:200, train acc:0.89, test acc:0.7087

# %% [markdown]
# ## Dropoutを使う場合

# %%
# coding: utf-8
import os
import sys
sys.path.append(os.pardir)  # 親ディレクトリのファイルをインポートするための設定
import numpy as np
import matplotlib.pyplot as plt
from dataset.mnist import load_mnist
from common.multi_layer_net_extend import MultiLayerNetExtend
from common.trainer import Trainer

(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

# 過学習を再現するために、学習データを削減
x_train = x_train[:300]
t_train = t_train[:300]

# Dropuoutの有無、割り合いの設定 ========================
use_dropout = True  # Dropoutなしのときの場合はFalseに
dropout_ratio = 0.2
# ====================================================

network = MultiLayerNetExtend(input_size=784, hidden_size_list=[100, 100, 100, 100, 100, 100],
                              output_size=10, use_dropout=use_dropout, dropout_ration=dropout_ratio)
trainer = Trainer(network, x_train, t_train, x_test, t_test,
                  epochs=301, mini_batch_size=100,
                  optimizer='sgd', optimizer_param={'lr': 0.01}, verbose=True)
trainer.train()

train_acc_list, test_acc_list = trainer.train_acc_list, trainer.test_acc_list

# グラフの描画==========
markers = {'train': 'o', 'test': 's'}
x = np.arange(len(train_acc_list))
plt.plot(x, train_acc_list, marker='o', label='train', markevery=10)
plt.plot(x, test_acc_list, marker='s', label='test', markevery=10)
plt.xlabel("epochs")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
plt.legend(loc='lower right')
plt.show()
# Out:
# train loss:2.30340270969
# === epoch:1, train acc:0.1, test acc:0.1064 ===
# train loss:2.30887762126
# train loss:2.31753386801
# train loss:2.30019632294
# === epoch:2, train acc:0.103333333333, test acc:0.1077 ===
# train loss:2.28408273739
# train loss:2.3097000394
# train loss:2.30808638975
# === epoch:3, train acc:0.116666666667, test acc:0.11 ===
# train loss:2.30203648456
# train loss:2.30097431645
# train loss:2.30022629669
# === epoch:4, train acc:0.12, test acc:0.1119 ===
# train loss:2.28873690652
# train loss:2.30962483062
# train loss:2.30007667174
# === epoch:5, train acc:0.123333333333, test acc:0.1151 ===
# train loss:2.31172136485
# train loss:2.31507069263
# train loss:2.29695152809
# === epoch:6, train acc:0.12, test acc:0.1186 ===
# train loss:2.29090009247
# train loss:2.29611509334
# train loss:2.28770519251
# === epoch:7, train acc:0.12, test acc:0.1162 ===
# train loss:2.27176881687
# train loss:2.30937347533
# train loss:2.298244121
# === epoch:8, train acc:0.12, test acc:0.1155 ===
# train loss:2.28919266831
# train loss:2.29134746788
# train loss:2.28471564936
# === epoch:9, train acc:0.12, test acc:0.1152 ===
# train loss:2.29852355264
# train loss:2.30217538697
# train loss:2.26695106426
# === epoch:10, train acc:0.116666666667, test acc:0.1144 ===
# train loss:2.28837420192
# train loss:2.27061460109
# train loss:2.28318177964
# === epoch:11, train acc:0.12, test acc:0.1134 ===
# train loss:2.27505573733
# train loss:2.30533107154
# train loss:2.29544298269
# === epoch:12, train acc:0.12, test acc:0.1135 ===
# train loss:2.27299460002
# train loss:2.2838748928
# train loss:2.28850867148
# === epoch:13, train acc:0.12, test acc:0.1124 ===
# train loss:2.28733874993
# train loss:2.28326924436
# train loss:2.2926698714
# === epoch:14, train acc:0.12, test acc:0.1129 ===
# train loss:2.26856859703
# train loss:2.27413185243
# train loss:2.2794542602
# === epoch:15, train acc:0.113333333333, test acc:0.1118 ===
# train loss:2.29895679755
# train loss:2.28764492152
# train loss:2.29385543429
# === epoch:16, train acc:0.12, test acc:0.1125 ===
# train loss:2.27407884676
# train loss:2.28104828658
# train loss:2.28695031517
# === epoch:17, train acc:0.12, test acc:0.1157 ===
# train loss:2.28070799624
# train loss:2.28272925961
# train loss:2.27869920855
# === epoch:18, train acc:0.126666666667, test acc:0.1173 ===
# train loss:2.27093641602
# train loss:2.26400448323
# train loss:2.26999216671
# === epoch:19, train acc:0.126666666667, test acc:0.12 ===
# train loss:2.27498706647
# train loss:2.28690420378
# train loss:2.27305464313
# === epoch:20, train acc:0.133333333333, test acc:0.1261 ===
# train loss:2.25952940888
# train loss:2.26767772043
# train loss:2.27779487314
# === epoch:21, train acc:0.136666666667, test acc:0.1273 ===
# train loss:2.28601715704
# train loss:2.27502135575
# train loss:2.28572371404
# === epoch:22, train acc:0.14, test acc:0.1327 ===
# train loss:2.26196400489
# train loss:2.26796328182
# train loss:2.26560999245
# === epoch:23, train acc:0.156666666667, test acc:0.1368 ===
# train loss:2.28623766403
# train loss:2.26843220554
# train loss:2.26359345669
# === epoch:24, train acc:0.156666666667, test acc:0.1404 ===
# train loss:2.27347408131
# train loss:2.26810040374
# train loss:2.26953911323
# === epoch:25, train acc:0.166666666667, test acc:0.1463 ===
# train loss:2.27074368118
# train loss:2.26907756994
# train loss:2.26295678302
# === epoch:26, train acc:0.166666666667, test acc:0.1504 ===
# train loss:2.25624881453
# train loss:2.2577891307
# train loss:2.2551886905
# === epoch:27, train acc:0.18, test acc:0.1555 ===
# train loss:2.24639021791
# train loss:2.25679645315
# train loss:2.2679924868
# === epoch:28, train acc:0.186666666667, test acc:0.1629 ===
# train loss:2.25422801658
# train loss:2.26026872662
# train loss:2.27724012675
# === epoch:29, train acc:0.2, test acc:0.1694 ===
# train loss:2.26415611217
# train loss:2.25491013839
# train loss:2.25388072939
# === epoch:30, train acc:0.186666666667, test acc:0.1723 ===
# train loss:2.24400741135
# train loss:2.24875586629
# train loss:2.24569898308
# === epoch:31, train acc:0.186666666667, test acc:0.1733 ===
# train loss:2.26577281444
# train loss:2.24510481616
# train loss:2.25920570797
# === epoch:32, train acc:0.186666666667, test acc:0.174 ===
# train loss:2.25583894898
# train loss:2.26757498565
# train loss:2.26487891848
# === epoch:33, train acc:0.2, test acc:0.1767 ===
# train loss:2.25058885167
# train loss:2.25357495526
# train loss:2.23409837546
# === epoch:34, train acc:0.206666666667, test acc:0.1808 ===
# train loss:2.24617369127
# train loss:2.24531058363
# train loss:2.24569907631
# === epoch:35, train acc:0.21, test acc:0.1813 ===
# train loss:2.26121779546
# train loss:2.24895378922
# train loss:2.26244847351
# === epoch:36, train acc:0.213333333333, test acc:0.1863 ===
# train loss:2.24101180759
# train loss:2.24316420298
# train loss:2.25907322176
# === epoch:37, train acc:0.21, test acc:0.1863 ===
# train loss:2.23892869268
# train loss:2.26924411815
# train loss:2.25979572854
# === epoch:38, train acc:0.213333333333, test acc:0.1904 ===
# train loss:2.230574357
# train loss:2.26395315961
# train loss:2.25206006102
# === epoch:39, train acc:0.226666666667, test acc:0.1987 ===
# train loss:2.24552012186
# train loss:2.23940546457
# train loss:2.24525719291
# === epoch:40, train acc:0.226666666667, test acc:0.1955 ===
# train loss:2.24878558331
# train loss:2.24740382518
# train loss:2.23914999309
# === epoch:41, train acc:0.216666666667, test acc:0.1927 ===
# train loss:2.26402400988
# train loss:2.26702792588
# train loss:2.24823768576
# === epoch:42, train acc:0.233333333333, test acc:0.2005 ===
# train loss:2.23624785949
# train loss:2.25117554982
# train loss:2.25760652898
# === epoch:43, train acc:0.226666666667, test acc:0.2003 ===
# train loss:2.2438026314
# train loss:2.25746670139
# train loss:2.23530024212
# === epoch:44, train acc:0.236666666667, test acc:0.2066 ===
# train loss:2.24943403827
# train loss:2.21967412376
# train loss:2.22681242156
# === epoch:45, train acc:0.233333333333, test acc:0.2077 ===
# train loss:2.22477534978
# train loss:2.23360823905
# train loss:2.23338883306
# === epoch:46, train acc:0.236666666667, test acc:0.2065 ===
# train loss:2.22877028239
# train loss:2.24075433821
# train loss:2.21213554342
# === epoch:47, train acc:0.243333333333, test acc:0.2109 ===
# train loss:2.23401739097
# train loss:2.23353214591
# train loss:2.21056230837
# === epoch:48, train acc:0.233333333333, test acc:0.2038 ===
# train loss:2.2274484323
# train loss:2.23283517553
# train loss:2.22423037363
# === epoch:49, train acc:0.226666666667, test acc:0.2067 ===
# train loss:2.23525847847
# train loss:2.24238359933
# train loss:2.21210660326
# === epoch:50, train acc:0.226666666667, test acc:0.2026 ===
# train loss:2.23641550912
# train loss:2.2277383802
# train loss:2.24060694088
# === epoch:51, train acc:0.226666666667, test acc:0.2009 ===
# train loss:2.1984753814
# train loss:2.21973302504
# train loss:2.2249554723
# === epoch:52, train acc:0.226666666667, test acc:0.2007 ===
# train loss:2.21772546034
# train loss:2.23212559806
# train loss:2.21833561611
# === epoch:53, train acc:0.23, test acc:0.2003 ===
# train loss:2.22760446023
# train loss:2.18555363001
# train loss:2.22857629631
# === epoch:54, train acc:0.233333333333, test acc:0.2037 ===
# train loss:2.22306327467
# train loss:2.2267084317
# train loss:2.20352420832
# === epoch:55, train acc:0.233333333333, test acc:0.1981 ===
# train loss:2.19946605767
# train loss:2.24247078679
# train loss:2.23593788422
# === epoch:56, train acc:0.25, test acc:0.2035 ===
# train loss:2.23497961814
# train loss:2.23640312138
# train loss:2.23144907767
# === epoch:57, train acc:0.256666666667, test acc:0.2078 ===
# train loss:2.20118890969
# train loss:2.23272747555
# train loss:2.21836619221
# === epoch:58, train acc:0.263333333333, test acc:0.2115 ===
# train loss:2.2225018943
# train loss:2.19781123599
# train loss:2.22851659024
# === epoch:59, train acc:0.246666666667, test acc:0.2082 ===
# train loss:2.2152312795
# train loss:2.21992173291
# train loss:2.23467916456
# === epoch:60, train acc:0.256666666667, test acc:0.212 ===
# train loss:2.21631119682
# train loss:2.17161396451
# train loss:2.20345804983
# === epoch:61, train acc:0.246666666667, test acc:0.2097 ===
# train loss:2.19482999823
# train loss:2.21945158743
# train loss:2.19946785703
# === epoch:62, train acc:0.24, test acc:0.2069 ===
# train loss:2.22881593516
# train loss:2.22713727482
# train loss:2.19270963587
# === epoch:63, train acc:0.233333333333, test acc:0.209 ===
# train loss:2.20157944196
# train loss:2.18789899456
# train loss:2.18374157066
# === epoch:64, train acc:0.23, test acc:0.2099 ===
# train loss:2.21901657427
# train loss:2.16841703017
# train loss:2.20195691795
# === epoch:65, train acc:0.246666666667, test acc:0.2145 ===
# train loss:2.19813623239
# train loss:2.20446988186
# train loss:2.19785681526
# === epoch:66, train acc:0.263333333333, test acc:0.2206 ===
# train loss:2.19467623884
# train loss:2.20501605096
# train loss:2.20460716377
# === epoch:67, train acc:0.256666666667, test acc:0.2183 ===
# train loss:2.19410579392
# train loss:2.16561514321
# train loss:2.1779308803
# === epoch:68, train acc:0.256666666667, test acc:0.2153 ===
# train loss:2.14331413726
# train loss:2.23207468645
# train loss:2.17494507097
# === epoch:69, train acc:0.25, test acc:0.2143 ===
# train loss:2.20816768956
# train loss:2.21592315333
# train loss:2.16454866653
# === epoch:70, train acc:0.253333333333, test acc:0.2179 ===
# train loss:2.22027125933
# train loss:2.16285328918
# train loss:2.18954209737
# === epoch:71, train acc:0.27, test acc:0.224 ===
# train loss:2.16208571065
# train loss:2.1718520796
# train loss:2.19969282683
# === epoch:72, train acc:0.266666666667, test acc:0.2235 ===
# train loss:2.18442248642
# train loss:2.17373025532
# train loss:2.16173169662
# === epoch:73, train acc:0.263333333333, test acc:0.2251 ===
# train loss:2.20490521987
# train loss:2.14654686301
# train loss:2.17612498307
# === epoch:74, train acc:0.266666666667, test acc:0.2249 ===
# train loss:2.20672080567
# train loss:2.17386304316
# train loss:2.19095293818
# === epoch:75, train acc:0.27, test acc:0.2256 ===
# train loss:2.20172022945
# train loss:2.17506660119
# train loss:2.18140676646
# === epoch:76, train acc:0.276666666667, test acc:0.2321 ===
# train loss:2.14138488827
# train loss:2.16849269867
# train loss:2.18080412832
# === epoch:77, train acc:0.28, test acc:0.2327 ===
# train loss:2.15692515612
# train loss:2.18040161225
# train loss:2.19931177089
# === epoch:78, train acc:0.283333333333, test acc:0.2349 ===
# train loss:2.13951742805
# train loss:2.20306845569
# train loss:2.16843403531
# === epoch:79, train acc:0.283333333333, test acc:0.2333 ===
# train loss:2.17199508913
# train loss:2.16893648424
# train loss:2.13490879143
# === epoch:80, train acc:0.286666666667, test acc:0.234 ===
# train loss:2.1827818848
# train loss:2.18599814392
# train loss:2.17265546863
# === epoch:81, train acc:0.29, test acc:0.237 ===
# train loss:2.20694522525
# train loss:2.15417466662
# train loss:2.16411400882
# === epoch:82, train acc:0.29, test acc:0.2375 ===
# train loss:2.1446434832
# train loss:2.18098626529
# train loss:2.16998895061
# === epoch:83, train acc:0.293333333333, test acc:0.2389 ===
# train loss:2.14820717297
# train loss:2.1776107238
# train loss:2.17325323508
# === epoch:84, train acc:0.293333333333, test acc:0.2378 ===
# train loss:2.15436769145
# train loss:2.11928719583
# train loss:2.14963621117
# === epoch:85, train acc:0.286666666667, test acc:0.2361 ===
# train loss:2.13966090632
# train loss:2.14486345609
# train loss:2.20616387609
# === epoch:86, train acc:0.303333333333, test acc:0.2408 ===
# train loss:2.11681022479
# train loss:2.18112091716
# train loss:2.16486606551
# === epoch:87, train acc:0.303333333333, test acc:0.2445 ===
# train loss:2.14490930625
# train loss:2.13305294142
# train loss:2.19246346664
# === epoch:88, train acc:0.306666666667, test acc:0.2456 ===
# train loss:2.13222357532
# train loss:2.13285148696
# train loss:2.12641637204
# === epoch:89, train acc:0.306666666667, test acc:0.2454 ===
# train loss:2.20366053581
# train loss:2.122961757
# train loss:2.15788268578
# === epoch:90, train acc:0.31, test acc:0.2508 ===
# train loss:2.13366118445
# train loss:2.14520429657
# train loss:2.14936775062
# === epoch:91, train acc:0.313333333333, test acc:0.2536 ===
# train loss:2.1498482431
# train loss:2.13121303669
# train loss:2.14282996532
# === epoch:92, train acc:0.313333333333, test acc:0.2547 ===
# train loss:2.1508663091
# train loss:2.1328411341
# train loss:2.06015060601
# === epoch:93, train acc:0.31, test acc:0.2504 ===
# train loss:2.1075850145
# train loss:2.13375259611
# train loss:2.1092582911
# === epoch:94, train acc:0.31, test acc:0.2515 ===
# train loss:2.17935909848
# train loss:2.14582325648
# train loss:2.12758904311
# === epoch:95, train acc:0.313333333333, test acc:0.2548 ===
# train loss:2.12112378497
# train loss:2.10838985404
# train loss:2.10653219297
# === epoch:96, train acc:0.316666666667, test acc:0.2548 ===
# train loss:2.10767540859
# train loss:2.08273564006
# train loss:2.11523371183
# === epoch:97, train acc:0.31, test acc:0.2521 ===
# train loss:2.08987356446
# train loss:2.10038265665
# train loss:2.12748878466
# === epoch:98, train acc:0.306666666667, test acc:0.2497 ===
# train loss:2.1435631485
# train loss:2.11402753521
# train loss:2.07126802556
# === epoch:99, train acc:0.306666666667, test acc:0.2517 ===
# train loss:2.15810197526
# train loss:2.14086382806
# train loss:2.13805325963
# === epoch:100, train acc:0.316666666667, test acc:0.2582 ===
# train loss:2.12527886225
# train loss:2.06433635779
# train loss:2.07117626015
# === epoch:101, train acc:0.316666666667, test acc:0.2583 ===
# train loss:2.05617445264
# train loss:2.02930941997
# train loss:2.0724723628
# === epoch:102, train acc:0.306666666667, test acc:0.2522 ===
# train loss:2.08512772741
# train loss:2.11419369926
# train loss:2.15596124368
# === epoch:103, train acc:0.313333333333, test acc:0.2575 ===
# train loss:2.08145744979
# train loss:2.1099214524
# train loss:2.11477058168
# === epoch:104, train acc:0.313333333333, test acc:0.2581 ===
# train loss:2.04624764124
# train loss:2.02890856098
# train loss:2.13231856866
# === epoch:105, train acc:0.316666666667, test acc:0.2594 ===
# train loss:2.11484816062
# train loss:2.02448340946
# train loss:2.11013603774
# === epoch:106, train acc:0.316666666667, test acc:0.259 ===
# train loss:2.10302208789
# train loss:2.10607502082
# train loss:2.11186672609
# === epoch:107, train acc:0.323333333333, test acc:0.2677 ===
# train loss:2.0984833975
# train loss:2.01734518522
# train loss:2.07582572398
# === epoch:108, train acc:0.33, test acc:0.2658 ===
# train loss:2.11622004903
# train loss:2.04188709526
# train loss:2.00430357398
# === epoch:109, train acc:0.33, test acc:0.2675 ===
# train loss:2.14462869142
# train loss:2.07687275097
# train loss:2.13236819978
# === epoch:110, train acc:0.343333333333, test acc:0.2726 ===
# train loss:2.08775016819
# train loss:2.1094518857
# train loss:2.10593622971
# === epoch:111, train acc:0.35, test acc:0.2805 ===
# train loss:2.10516489337
# train loss:2.06572359965
# train loss:2.0721725811
# === epoch:112, train acc:0.36, test acc:0.2878 ===
# train loss:2.11166452605
# train loss:2.04590343331
# train loss:2.07292171082
# === epoch:113, train acc:0.36, test acc:0.2912 ===
# train loss:2.04234375281
# train loss:2.15300158184
# train loss:2.0769280971
# === epoch:114, train acc:0.366666666667, test acc:0.297 ===
# train loss:2.01159615239
# train loss:2.02016719128
# train loss:2.00947528241
# === epoch:115, train acc:0.363333333333, test acc:0.2989 ===
# train loss:2.01004396012
# train loss:2.05645336455
# train loss:2.01859035347
# === epoch:116, train acc:0.356666666667, test acc:0.2955 ===
# train loss:2.09248989059
# train loss:2.02351666181
# train loss:2.09579067276
# === epoch:117, train acc:0.363333333333, test acc:0.3008 ===
# train loss:2.06776170251
# train loss:2.02304662591
# train loss:2.06884802253
# === epoch:118, train acc:0.363333333333, test acc:0.3031 ===
# train loss:2.01341700454
# train loss:1.96758454135
# train loss:2.00291448692
# === epoch:119, train acc:0.37, test acc:0.2959 ===
# train loss:2.08615962897
# train loss:2.04880551854
# train loss:2.03907571672
# === epoch:120, train acc:0.373333333333, test acc:0.2975 ===
# train loss:2.05226445208
# train loss:2.03808190247
# train loss:2.05914465127
# === epoch:121, train acc:0.373333333333, test acc:0.3058 ===
# train loss:2.02903736442
# train loss:1.9753438917
# train loss:2.08395777324
# === epoch:122, train acc:0.396666666667, test acc:0.3127 ===
# train loss:2.0047846013
# train loss:2.02242145268
# train loss:1.91604753093
# === epoch:123, train acc:0.393333333333, test acc:0.3119 ===
# train loss:2.01350636563
# train loss:1.99523807617
# train loss:2.01446254385
# === epoch:124, train acc:0.39, test acc:0.3144 ===
# train loss:2.03585302634
# train loss:2.01493319883
# train loss:2.04510568291
# === epoch:125, train acc:0.403333333333, test acc:0.3223 ===
# train loss:1.97043388519
# train loss:1.96121473336
# train loss:2.0066730041
# === epoch:126, train acc:0.403333333333, test acc:0.3209 ===
# train loss:2.03218332776
# train loss:2.00001260468
# train loss:2.02850917686
# === epoch:127, train acc:0.4, test acc:0.3219 ===
# train loss:2.01550285685
# train loss:1.98622991558
# train loss:1.94879857112
# === epoch:128, train acc:0.403333333333, test acc:0.3212 ===
# train loss:2.03361277003
# train loss:1.91660897054
# train loss:2.02402936689
# === epoch:129, train acc:0.4, test acc:0.3205 ===
# train loss:2.011116165
# train loss:1.94225069698
# train loss:1.99905418805
# === epoch:130, train acc:0.403333333333, test acc:0.3199 ===
# train loss:1.91423288745
# train loss:1.93867410757
# train loss:2.01562690345
# === epoch:131, train acc:0.403333333333, test acc:0.3173 ===
# train loss:2.06624641261
# train loss:1.96982189087
# train loss:1.91243936745
# === epoch:132, train acc:0.413333333333, test acc:0.3273 ===
# train loss:1.99439936956
# train loss:2.01414626428
# train loss:1.95666120508
# === epoch:133, train acc:0.41, test acc:0.3243 ===
# train loss:2.03535709377
# train loss:2.04134405743
# train loss:2.05759622026
# === epoch:134, train acc:0.413333333333, test acc:0.3287 ===
# train loss:1.97928160142
# train loss:1.97637406065
# train loss:1.95808362351
# === epoch:135, train acc:0.416666666667, test acc:0.3333 ===
# train loss:1.96343004448
# train loss:1.94461497976
# train loss:1.99956754768
# === epoch:136, train acc:0.436666666667, test acc:0.3383 ===
# train loss:1.95351077209
# train loss:1.90813684942
# train loss:1.8717715985
# === epoch:137, train acc:0.426666666667, test acc:0.3366 ===
# train loss:2.04015150251
# train loss:2.01559525609
# train loss:1.90417353914
# === epoch:138, train acc:0.43, test acc:0.3398 ===
# train loss:2.00627051798
# train loss:2.01724063581
# train loss:2.08502620528
# === epoch:139, train acc:0.446666666667, test acc:0.3497 ===
# train loss:1.99757741347
# train loss:1.94964266978
# train loss:1.87629086354
# === epoch:140, train acc:0.446666666667, test acc:0.3482 ===
# train loss:1.95930469131
# train loss:2.00248219017
# train loss:1.97882969328
# === epoch:141, train acc:0.446666666667, test acc:0.3502 ===
# train loss:1.90244466883
# train loss:1.85364335927
# train loss:1.92649101654
# === epoch:142, train acc:0.436666666667, test acc:0.3485 ===
# train loss:1.94979794877
# train loss:1.97425299007
# train loss:1.97884486738
# === epoch:143, train acc:0.443333333333, test acc:0.3526 ===
# train loss:1.9395897459
# train loss:1.89614403016
# train loss:1.96623946326
# === epoch:144, train acc:0.443333333333, test acc:0.353 ===
# train loss:1.97116259079
# train loss:2.02670883004
# train loss:1.9179666429
# === epoch:145, train acc:0.443333333333, test acc:0.3605 ===
# train loss:1.90107345607
# train loss:1.8150296999
# train loss:1.88423792656
# === epoch:146, train acc:0.446666666667, test acc:0.3546 ===
# train loss:1.9201688103
# train loss:2.00541260681
# train loss:1.91182160099
# === epoch:147, train acc:0.46, test acc:0.3639 ===
# train loss:1.98123537866
# train loss:1.94660519698
# train loss:1.93179739111
# === epoch:148, train acc:0.456666666667, test acc:0.3673 ===
# train loss:1.98576225341
# train loss:1.91594958966
# train loss:1.87786710366
# === epoch:149, train acc:0.46, test acc:0.3699 ===
# train loss:1.98830570661
# train loss:1.91846974657
# train loss:1.88966943627
# === epoch:150, train acc:0.466666666667, test acc:0.3747 ===
# train loss:1.92305614943
# train loss:1.90053227873
# train loss:1.98179339671
# === epoch:151, train acc:0.47, test acc:0.3813 ===
# train loss:1.86326436334
# train loss:1.82130527904
# train loss:1.8961657222
# === epoch:152, train acc:0.476666666667, test acc:0.3802 ===
# train loss:1.86612762428
# train loss:1.91690462866
# train loss:1.89877236405
# === epoch:153, train acc:0.473333333333, test acc:0.379 ===
# train loss:1.98064984999
# train loss:1.85400657311
# train loss:1.94022529747
# === epoch:154, train acc:0.473333333333, test acc:0.3802 ===
# train loss:1.84829880564
# train loss:1.89086588481
# train loss:1.89551063217
# === epoch:155, train acc:0.483333333333, test acc:0.3872 ===
# train loss:1.77133570721
# train loss:1.94337376364
# train loss:1.96295181707
# === epoch:156, train acc:0.483333333333, test acc:0.3911 ===
# train loss:1.95720635972
# train loss:1.90270574006
# train loss:1.79508246896
# === epoch:157, train acc:0.483333333333, test acc:0.3925 ===
# train loss:1.92439455454
# train loss:1.93108449553
# train loss:1.89361599684
# === epoch:158, train acc:0.49, test acc:0.3971 ===
# train loss:1.81922325741
# train loss:1.84816955817
# train loss:1.92175296966
# === epoch:159, train acc:0.49, test acc:0.3957 ===
# train loss:1.87895603542
# train loss:1.96802529654
# train loss:1.83063594287
# === epoch:160, train acc:0.49, test acc:0.3974 ===
# train loss:1.92563330993
# train loss:1.86591881693
# train loss:1.85576047572
# === epoch:161, train acc:0.493333333333, test acc:0.3994 ===
# train loss:1.96590688673
# train loss:1.80693517737
# train loss:1.93151967452
# === epoch:162, train acc:0.503333333333, test acc:0.4048 ===
# train loss:1.96324274442
# train loss:1.87007071081
# train loss:1.70502102642
# === epoch:163, train acc:0.49, test acc:0.4007 ===
# train loss:1.89971074441
# train loss:1.82318096534
# train loss:1.88042832881
# === epoch:164, train acc:0.51, test acc:0.4054 ===
# train loss:1.90649844699
# train loss:1.84566602645
# train loss:1.83101132119
# === epoch:165, train acc:0.516666666667, test acc:0.406 ===
# train loss:1.88450166463
# train loss:1.87213456489
# train loss:1.92748698322
# === epoch:166, train acc:0.52, test acc:0.409 ===
# train loss:1.93728702526
# train loss:1.84919348076
# train loss:1.85507526451
# === epoch:167, train acc:0.523333333333, test acc:0.4116 ===
# train loss:1.89756393584
# train loss:1.84519871561
# train loss:1.78422415827
# === epoch:168, train acc:0.523333333333, test acc:0.4128 ===
# train loss:1.73653081858
# train loss:1.83164703844
# train loss:1.77284628839
# === epoch:169, train acc:0.516666666667, test acc:0.4092 ===
# train loss:1.74446592256
# train loss:1.90553052733
# train loss:1.83365845281
# === epoch:170, train acc:0.526666666667, test acc:0.4104 ===
# train loss:1.77686965023
# train loss:1.85092203462
# train loss:1.87232037977
# === epoch:171, train acc:0.53, test acc:0.4108 ===
# train loss:1.8785298712
# train loss:1.80170821404
# train loss:1.91614078217
# === epoch:172, train acc:0.526666666667, test acc:0.415 ===
# train loss:1.75861703634
# train loss:1.86922514994
# train loss:1.81906309694
# === epoch:173, train acc:0.526666666667, test acc:0.4104 ===
# train loss:1.95478186122
# train loss:1.78664691366
# train loss:1.81962634214
# === epoch:174, train acc:0.526666666667, test acc:0.4182 ===
# train loss:1.89090044845
# train loss:1.77167435029
# train loss:1.83359297893
# === epoch:175, train acc:0.526666666667, test acc:0.4127 ===
# train loss:1.88610981987
# train loss:1.76758399554
# train loss:1.91987847183
# === epoch:176, train acc:0.523333333333, test acc:0.4134 ===
# train loss:1.75823333102
# train loss:1.8253733615
# train loss:1.73542155145
# === epoch:177, train acc:0.523333333333, test acc:0.4124 ===
# train loss:1.91655754166
# train loss:1.80569673805
# train loss:1.76638353409
# === epoch:178, train acc:0.526666666667, test acc:0.415 ===
# train loss:1.73223930503
# train loss:1.82240657273
# train loss:1.80659335459
# === epoch:179, train acc:0.52, test acc:0.4213 ===
# train loss:1.85101368574
# train loss:1.76161601034
# train loss:1.92236490592
# === epoch:180, train acc:0.523333333333, test acc:0.4242 ===
# train loss:1.78895750625
# train loss:1.86301571053
# train loss:1.87086437223
# === epoch:181, train acc:0.523333333333, test acc:0.4223 ===
# train loss:1.73520814785
# train loss:1.81167880062
# train loss:1.75855557523
# === epoch:182, train acc:0.53, test acc:0.4215 ===
# train loss:1.78409003316
# train loss:1.84260225941
# train loss:1.82131045879
# === epoch:183, train acc:0.53, test acc:0.4297 ===
# train loss:1.80528490612
# train loss:1.80114212965
# train loss:1.74358557133
# === epoch:184, train acc:0.533333333333, test acc:0.429 ===
# train loss:1.83766676712
# train loss:1.75653041731
# train loss:1.82632123398
# === epoch:185, train acc:0.54, test acc:0.4314 ===
# train loss:1.73532685548
# train loss:1.83024938061
# train loss:1.80588257765
# === epoch:186, train acc:0.536666666667, test acc:0.4332 ===
# train loss:1.74485003908
# train loss:1.79828029039
# train loss:1.74952469219
# === epoch:187, train acc:0.546666666667, test acc:0.436 ===
# train loss:1.69374244214
# train loss:1.80279380885
# train loss:1.72647860678
# === epoch:188, train acc:0.55, test acc:0.4375 ===
# train loss:1.75793101963
# train loss:1.87166085067
# train loss:1.74982063981
# === epoch:189, train acc:0.55, test acc:0.4402 ===
# train loss:1.64116114505
# train loss:1.70914118815
# train loss:1.77739542027
# === epoch:190, train acc:0.563333333333, test acc:0.4429 ===
# train loss:1.79183763165
# train loss:1.76483916205
# train loss:1.86879929243
# === epoch:191, train acc:0.563333333333, test acc:0.4467 ===
# train loss:1.78720119659
# train loss:1.69493445794
# train loss:1.81150351234
# === epoch:192, train acc:0.56, test acc:0.4501 ===
# train loss:1.74924227318
# train loss:1.76221016116
# train loss:1.64066629936
# === epoch:193, train acc:0.556666666667, test acc:0.448 ===
# train loss:1.72076637446
# train loss:1.82751869693
# train loss:1.82745483821
# === epoch:194, train acc:0.55, test acc:0.4514 ===
# train loss:1.81109030805
# train loss:1.78708109454
# train loss:1.6885737086
# === epoch:195, train acc:0.553333333333, test acc:0.4486 ===
# train loss:1.76668179741
# train loss:1.69007436751
# train loss:1.75441406051
# === epoch:196, train acc:0.556666666667, test acc:0.451 ===
# train loss:1.65860316734
# train loss:1.80904861234
# train loss:1.72047947666
# === epoch:197, train acc:0.556666666667, test acc:0.452 ===
# train loss:1.85594162233
# train loss:1.58317037958
# train loss:1.67513733694
# === epoch:198, train acc:0.56, test acc:0.4531 ===
# train loss:1.73898676102
# train loss:1.79466113186
# train loss:1.70216275153
# === epoch:199, train acc:0.57, test acc:0.4557 ===
# train loss:1.76601709136
# train loss:1.67393780064
# train loss:1.66093459769
# === epoch:200, train acc:0.566666666667, test acc:0.4545 ===
# train loss:1.69913905512
# train loss:1.59792092495
# train loss:1.7836942581
# === epoch:201, train acc:0.573333333333, test acc:0.4571 ===
# train loss:1.76919254018
# train loss:1.63653817493
# train loss:1.67974855114
# === epoch:202, train acc:0.576666666667, test acc:0.4584 ===
# train loss:1.69306345446
# train loss:1.65237625984
# train loss:1.79368317342
# === epoch:203, train acc:0.58, test acc:0.4608 ===
# train loss:1.73588946905
# train loss:1.69339812176
# train loss:1.71955965667
# === epoch:204, train acc:0.583333333333, test acc:0.4608 ===
# train loss:1.65883059267
# train loss:1.72262257011
# train loss:1.64292197573
# === epoch:205, train acc:0.586666666667, test acc:0.4617 ===
# train loss:1.80338106079
# train loss:1.61820079011
# train loss:1.60892650501
# === epoch:206, train acc:0.586666666667, test acc:0.4612 ===
# train loss:1.70143881447
# train loss:1.72436734524
# train loss:1.70490530078
# === epoch:207, train acc:0.59, test acc:0.4699 ===
# train loss:1.68522250886
# train loss:1.71376335857
# train loss:1.73419335516
# === epoch:208, train acc:0.593333333333, test acc:0.4715 ===
# train loss:1.69431792367
# train loss:1.73015930216
# train loss:1.69328706602
# === epoch:209, train acc:0.59, test acc:0.4715 ===
# train loss:1.77039713141
# train loss:1.57539222356
# train loss:1.45242720471
# === epoch:210, train acc:0.59, test acc:0.4733 ===
# train loss:1.69773583446
# train loss:1.63244886394
# train loss:1.75721932585
# === epoch:211, train acc:0.593333333333, test acc:0.4763 ===
# train loss:1.79925312853
# train loss:1.81111076062
# train loss:1.60161651178
# === epoch:212, train acc:0.6, test acc:0.4767 ===
# train loss:1.63338198604
# train loss:1.5515382394
# train loss:1.65390315259
# === epoch:213, train acc:0.59, test acc:0.4769 ===
# train loss:1.5372737045
# train loss:1.78593298066
# train loss:1.60260113595
# === epoch:214, train acc:0.596666666667, test acc:0.4765 ===
# train loss:1.72352203816
# train loss:1.68279547595
# train loss:1.63233175277
# === epoch:215, train acc:0.593333333333, test acc:0.476 ===
# train loss:1.66680475254
# train loss:1.62600886096
# train loss:1.50383031778
# === epoch:216, train acc:0.593333333333, test acc:0.4762 ===
# train loss:1.64296672459
# train loss:1.71683168052
# train loss:1.58308642435
# === epoch:217, train acc:0.593333333333, test acc:0.4791 ===
# train loss:1.56743705226
# train loss:1.56602129379
# train loss:1.5074191137
# === epoch:218, train acc:0.593333333333, test acc:0.4807 ===
# train loss:1.60145068553
# train loss:1.67352655252
# train loss:1.61122690353
# === epoch:219, train acc:0.596666666667, test acc:0.4807 ===
# train loss:1.66186639749
# train loss:1.67352118167
# train loss:1.65360035297
# === epoch:220, train acc:0.593333333333, test acc:0.482 ===
# train loss:1.64365437633
# train loss:1.63538852661
# train loss:1.81489727096
# === epoch:221, train acc:0.603333333333, test acc:0.4834 ===
# train loss:1.55266207036
# train loss:1.65850584161
# train loss:1.71293911081
# === epoch:222, train acc:0.6, test acc:0.4878 ===
# train loss:1.67998594625
# train loss:1.55105708686
# train loss:1.66288864958
# === epoch:223, train acc:0.606666666667, test acc:0.4893 ===
# train loss:1.57128198645
# train loss:1.70077258044
# train loss:1.70690322437
# === epoch:224, train acc:0.61, test acc:0.4913 ===
# train loss:1.67942812137
# train loss:1.58730830249
# train loss:1.68456457503
# === epoch:225, train acc:0.606666666667, test acc:0.4921 ===
# train loss:1.61443303925
# train loss:1.61324012383
# train loss:1.56028600519
# === epoch:226, train acc:0.606666666667, test acc:0.4946 ===
# train loss:1.52184801094
# train loss:1.56596278286
# train loss:1.58909963165
# === epoch:227, train acc:0.606666666667, test acc:0.4939 ===
# train loss:1.48824627899
# train loss:1.61024687017
# train loss:1.4909447834
# === epoch:228, train acc:0.61, test acc:0.4981 ===
# train loss:1.55826967693
# train loss:1.4430729834
# train loss:1.52621835746
# === epoch:229, train acc:0.603333333333, test acc:0.4985 ===
# train loss:1.523521193
# train loss:1.47764929121
# train loss:1.61497645084
# === epoch:230, train acc:0.61, test acc:0.4998 ===
# train loss:1.38936153185
# train loss:1.5868349711
# train loss:1.5671800868
# === epoch:231, train acc:0.613333333333, test acc:0.499 ===
# train loss:1.5026523837
# train loss:1.63149277093
# train loss:1.64697223866
# === epoch:232, train acc:0.61, test acc:0.5018 ===
# train loss:1.5826268844
# train loss:1.46075065374
# train loss:1.45048165158
# === epoch:233, train acc:0.613333333333, test acc:0.5011 ===
# train loss:1.62182424583
# train loss:1.60749923218
# train loss:1.53152626478
# === epoch:234, train acc:0.61, test acc:0.5033 ===
# train loss:1.62099283234
# train loss:1.52947475843
# train loss:1.55686019379
# === epoch:235, train acc:0.613333333333, test acc:0.5028 ===
# train loss:1.57615879593
# train loss:1.5059005034
# train loss:1.59209898668
# === epoch:236, train acc:0.62, test acc:0.5054 ===
# train loss:1.43209920426
# train loss:1.57385249845
# train loss:1.38397095037
# === epoch:237, train acc:0.63, test acc:0.5086 ===
# train loss:1.46997386423
# train loss:1.54635577019
# train loss:1.5498245082
# === epoch:238, train acc:0.636666666667, test acc:0.5119 ===
# train loss:1.40203499822
# train loss:1.55230126046
# train loss:1.50825224897
# === epoch:239, train acc:0.633333333333, test acc:0.5096 ===
# train loss:1.57025790476
# train loss:1.52241937945
# train loss:1.44599639351
# === epoch:240, train acc:0.626666666667, test acc:0.5097 ===
# train loss:1.439270452
# train loss:1.55357906471
# train loss:1.35662229037
# === epoch:241, train acc:0.63, test acc:0.5101 ===
# train loss:1.44012120678
# train loss:1.56515768164
# train loss:1.61192421934
# === epoch:242, train acc:0.63, test acc:0.5107 ===
# train loss:1.46098943747
# train loss:1.51732523182
# train loss:1.49965875846
# === epoch:243, train acc:0.63, test acc:0.5134 ===
# train loss:1.47965837902
# train loss:1.32430853463
# train loss:1.55802169645
# === epoch:244, train acc:0.63, test acc:0.5143 ===
# train loss:1.47083867842
# train loss:1.49827506675
# train loss:1.54802878334
# === epoch:245, train acc:0.633333333333, test acc:0.517 ===
# train loss:1.65480172389
# train loss:1.44837595864
# train loss:1.47331063931
# === epoch:246, train acc:0.633333333333, test acc:0.5187 ===
# train loss:1.48312090393
# train loss:1.42480074827
# train loss:1.54015722792
# === epoch:247, train acc:0.633333333333, test acc:0.5169 ===
# train loss:1.45772274806
# train loss:1.3782504744
# train loss:1.5106383329
# === epoch:248, train acc:0.636666666667, test acc:0.5164 ===
# train loss:1.44047866803
# train loss:1.52108594166
# train loss:1.41627059486
# === epoch:249, train acc:0.623333333333, test acc:0.5133 ===
# train loss:1.50249402598
# train loss:1.58669674391
# train loss:1.48546163265
# === epoch:250, train acc:0.633333333333, test acc:0.5196 ===
# train loss:1.43774615129
# train loss:1.47906094593
# train loss:1.47431983501
# === epoch:251, train acc:0.643333333333, test acc:0.5212 ===
# train loss:1.40047454489
# train loss:1.49577178811
# train loss:1.40324066244
# === epoch:252, train acc:0.643333333333, test acc:0.5233 ===
# train loss:1.40702702973
# train loss:1.54473905915
# train loss:1.50561000659
# === epoch:253, train acc:0.64, test acc:0.526 ===
# train loss:1.58369023168
# train loss:1.46572790799
# train loss:1.54141468434
# === epoch:254, train acc:0.65, test acc:0.529 ===
# train loss:1.37273423114
# train loss:1.29865094496
# train loss:1.41046467186
# === epoch:255, train acc:0.643333333333, test acc:0.5268 ===
# train loss:1.407007276
# train loss:1.3802733806
# train loss:1.4224887801
# === epoch:256, train acc:0.64, test acc:0.531 ===
# train loss:1.29003572636
# train loss:1.37942144117
# train loss:1.42397693508
# === epoch:257, train acc:0.643333333333, test acc:0.5289 ===
# train loss:1.42187236171
# train loss:1.48569909784
# train loss:1.36343055081
# === epoch:258, train acc:0.646666666667, test acc:0.5315 ===
# train loss:1.44782710019
# train loss:1.30108502719
# train loss:1.43559782458
# === epoch:259, train acc:0.643333333333, test acc:0.5309 ===
# train loss:1.3468885816
# train loss:1.3861520852
# train loss:1.63839936808
# === epoch:260, train acc:0.646666666667, test acc:0.5331 ===
# train loss:1.50379684159
# train loss:1.38083662172
# train loss:1.43827576849
# === epoch:261, train acc:0.653333333333, test acc:0.5361 ===
# train loss:1.47349469814
# train loss:1.48664741495
# train loss:1.45219007866
# === epoch:262, train acc:0.65, test acc:0.5395 ===
# train loss:1.32141349328
# train loss:1.46944986214
# train loss:1.38251681541
# === epoch:263, train acc:0.653333333333, test acc:0.5378 ===
# train loss:1.36064023376
# train loss:1.35423974185
# train loss:1.57776993172
# === epoch:264, train acc:0.65, test acc:0.5404 ===
# train loss:1.48178240123
# train loss:1.41887862783
# train loss:1.48686970885
# === epoch:265, train acc:0.65, test acc:0.5432 ===
# train loss:1.53008011053
# train loss:1.36152920596
# train loss:1.52950515554
# === epoch:266, train acc:0.653333333333, test acc:0.5468 ===
# train loss:1.47570018061
# train loss:1.36806656105
# train loss:1.52009959927
# === epoch:267, train acc:0.653333333333, test acc:0.5469 ===
# train loss:1.47746980738
# train loss:1.48919868279
# train loss:1.50615454974
# === epoch:268, train acc:0.656666666667, test acc:0.5458 ===
# train loss:1.41533292255
# train loss:1.42280194912
# train loss:1.375358912
# === epoch:269, train acc:0.656666666667, test acc:0.5461 ===
# train loss:1.32650624347
# train loss:1.37127121362
# train loss:1.47572504375
# === epoch:270, train acc:0.656666666667, test acc:0.5474 ===
# train loss:1.35492774224
# train loss:1.44734164619
# train loss:1.38507585515
# === epoch:271, train acc:0.666666666667, test acc:0.5489 ===
# train loss:1.39002960512
# train loss:1.23994349809
# train loss:1.35074371561
# === epoch:272, train acc:0.67, test acc:0.5516 ===
# train loss:1.18018661002
# train loss:1.30624256886
# train loss:1.19196813945
# === epoch:273, train acc:0.67, test acc:0.5508 ===
# train loss:1.46277596693
# train loss:1.33318197783
# train loss:1.48568268375
# === epoch:274, train acc:0.66, test acc:0.5491 ===
# train loss:1.3588377095
# train loss:1.33042430337
# train loss:1.3358037208
# === epoch:275, train acc:0.66, test acc:0.5497 ===
# train loss:1.46944249525
# train loss:1.22044816601
# train loss:1.26638884813
# === epoch:276, train acc:0.666666666667, test acc:0.5509 ===
# train loss:1.40752647632
# train loss:1.42103179987
# train loss:1.31231462777
# === epoch:277, train acc:0.67, test acc:0.56 ===
# train loss:1.34970285167
# train loss:1.26185961095
# train loss:1.51384631068
# === epoch:278, train acc:0.67, test acc:0.5574 ===
# train loss:1.28245933415
# train loss:1.27807515718
# train loss:1.34452899447
# === epoch:279, train acc:0.666666666667, test acc:0.5606 ===
# train loss:1.31381461094
# train loss:1.15103451886
# train loss:1.36744730586
# === epoch:280, train acc:0.663333333333, test acc:0.5562 ===
# train loss:1.33721469942
# train loss:1.25130232911
# train loss:1.21162345788
# === epoch:281, train acc:0.66, test acc:0.5564 ===
# train loss:1.3364679381
# train loss:1.18357886286
# train loss:1.32746148058
# === epoch:282, train acc:0.663333333333, test acc:0.5591 ===
# train loss:1.29366018682
# train loss:1.28240676745
# train loss:1.17367873932
# === epoch:283, train acc:0.673333333333, test acc:0.5654 ===
# train loss:1.14399125005
# train loss:1.33820393562
# train loss:1.23692571028
# === epoch:284, train acc:0.683333333333, test acc:0.5686 ===
# train loss:1.1987960274
# train loss:1.14361092375
# train loss:1.16716346756
# === epoch:285, train acc:0.69, test acc:0.5656 ===
# train loss:1.30550652308
# train loss:1.28226138868
# train loss:1.40616214729
# === epoch:286, train acc:0.686666666667, test acc:0.5677 ===
# train loss:1.33316897923
# train loss:1.36483137169
# train loss:1.26648073074
# === epoch:287, train acc:0.69, test acc:0.5739 ===
# train loss:1.34125599035
# train loss:1.1561596987
# train loss:1.15619840311
# === epoch:288, train acc:0.693333333333, test acc:0.5717 ===
# train loss:1.29738821661
# train loss:1.29455237045
# train loss:1.11894645426
# === epoch:289, train acc:0.696666666667, test acc:0.5743 ===
# train loss:1.355073772
# train loss:1.23462069882
# train loss:1.25608362169
# === epoch:290, train acc:0.696666666667, test acc:0.5745 ===
# train loss:1.22415538341
# train loss:1.28656166704
# train loss:1.15210495287
# === epoch:291, train acc:0.693333333333, test acc:0.5765 ===
# train loss:1.10782583136
# train loss:1.25925944988
# train loss:1.09704694164
# === epoch:292, train acc:0.69, test acc:0.5744 ===
# train loss:1.15813382297
# train loss:1.32778863816
# train loss:1.26323446824
# === epoch:293, train acc:0.686666666667, test acc:0.5748 ===
# train loss:1.05271066854
# train loss:1.29784409241
# train loss:1.19823767977
# === epoch:294, train acc:0.69, test acc:0.5735 ===
# train loss:1.15201597576
# train loss:1.09963702111
# train loss:1.19669237586
# === epoch:295, train acc:0.693333333333, test acc:0.5752 ===
# train loss:1.13900360509
# train loss:1.24406555617
# train loss:1.15199136914
# === epoch:296, train acc:0.696666666667, test acc:0.5756 ===
# train loss:1.15215565659
# train loss:1.1333131157
# train loss:0.998221139361
# === epoch:297, train acc:0.7, test acc:0.5738 ===
# train loss:1.09734327823
# train loss:1.27469916453
# train loss:1.1385865274
# === epoch:298, train acc:0.696666666667, test acc:0.5723 ===
# train loss:1.15149124262
# train loss:1.11477537659
# train loss:1.18345825152
# === epoch:299, train acc:0.7, test acc:0.5748 ===
# train loss:1.18210796779
# train loss:1.15285052501
# train loss:1.04717167912
# === epoch:300, train acc:0.7, test acc:0.5768 ===
# train loss:1.31924887034
# train loss:1.24834663279
# train loss:1.21378567514
# === epoch:301, train acc:0.696666666667, test acc:0.5797 ===
# train loss:1.06741997795
# train loss:1.21796941574
# =============== Final Test Accuracy ===============
# test acc:0.5816

# %% [markdown]
# ## ハイパーパラメータの調整

# %%
# coding: utf-8
import sys, os
sys.path.append(os.pardir)  # 親ディレクトリのファイルをインポートするための設定
import numpy as np
import matplotlib.pyplot as plt
from dataset.mnist import load_mnist
from common.multi_layer_net import MultiLayerNet
from common.util import shuffle_dataset
from common.trainer import Trainer

(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

# 高速化のため訓練データの削減
x_train = x_train[:500]
t_train = t_train[:500]

# 検証データの分離
validation_rate = 0.20
validation_num = x_train.shape[0] * validation_rate
x_train, t_train = shuffle_dataset(x_train, t_train)
x_val = x_train[:validation_num]
t_val = t_train[:validation_num]
x_train = x_train[validation_num:]
t_train = t_train[validation_num:]


def __train(lr, weight_decay, epocs=50):
    network = MultiLayerNet(input_size=784, hidden_size_list=[100, 100, 100, 100, 100, 100],
                            output_size=10, weight_decay_lambda=weight_decay)
    trainer = Trainer(network, x_train, t_train, x_val, t_val,
                      epochs=epocs, mini_batch_size=100,
                      optimizer='sgd', optimizer_param={'lr': lr}, verbose=False)
    trainer.train()

    return trainer.test_acc_list, trainer.train_acc_list


# ハイパーパラメータのランダム探索======================================
optimization_trial = 100
results_val = {}
results_train = {}
for _ in range(optimization_trial):
    # 探索したハイパーパラメータの範囲を指定===============
    weight_decay = 10 ** np.random.uniform(-8, -4)
    lr = 10 ** np.random.uniform(-6, -2)
    # ================================================

    val_acc_list, train_acc_list = __train(lr, weight_decay)
    print("val acc:" + str(val_acc_list[-1]) + " | lr:" + str(lr) + ", weight decay:" + str(weight_decay))
    key = "lr:" + str(lr) + ", weight decay:" + str(weight_decay)
    results_val[key] = val_acc_list
    results_train[key] = train_acc_list

# グラフの描画========================================================
print("=========== Hyper-Parameter Optimization Result ===========")
graph_draw_num = 20
col_num = 5
row_num = int(np.ceil(graph_draw_num / col_num))
i = 0

for key, val_acc_list in sorted(results_val.items(), key=lambda x:x[1][-1], reverse=True):
    print("Best-" + str(i+1) + "(val acc:" + str(val_acc_list[-1]) + ") | " + key)

    plt.subplot(row_num, col_num, i+1)
    plt.title("Best-" + str(i+1))
    plt.ylim(0.0, 1.0)
    if i % 5: plt.yticks([])
    plt.xticks([])
    x = np.arange(len(val_acc_list))
    plt.plot(x, val_acc_list)
    plt.plot(x, results_train[key], "--")
    i += 1

    if i >= graph_draw_num:
        break

plt.show()
# Out:
# //anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:21: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# //anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:22: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# //anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:23: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# //anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:24: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# val acc:0.11 | lr:0.0007915177548709994, weight decay:1.9750228052868804e-08
# val acc:0.11 | lr:6.423383076755041e-05, weight decay:4.947645142451251e-05
# val acc:0.22 | lr:0.001011529847370458, weight decay:1.3674845482607423e-06
# val acc:0.06 | lr:0.0001397377618839767, weight decay:4.598108753370183e-08
# val acc:0.47 | lr:0.002375569122031199, weight decay:1.519221345384572e-08
# val acc:0.13 | lr:0.00012186245408056916, weight decay:1.3747330922392844e-06
# val acc:0.6 | lr:0.0038396010559483564, weight decay:6.403676508719336e-07
# val acc:0.05 | lr:2.8682322018697302e-05, weight decay:2.2072497110612024e-05
# val acc:0.13 | lr:7.327797260635967e-06, weight decay:3.8584286898639644e-07
# val acc:0.51 | lr:0.0041229437581514665, weight decay:6.96289016818388e-07
# val acc:0.08 | lr:2.215115577577531e-06, weight decay:2.6385805178557695e-07
# val acc:0.12 | lr:4.085257391382609e-06, weight decay:9.001122150870382e-06
# val acc:0.22 | lr:0.002076394631900211, weight decay:2.0920802304153736e-07
# val acc:0.26 | lr:0.0013797097384103904, weight decay:4.0760743664319584e-07
# val acc:0.44 | lr:0.002719917652844227, weight decay:4.556238875731326e-08
# val acc:0.05 | lr:2.000074800740494e-05, weight decay:1.4283607341182188e-07
# val acc:0.08 | lr:5.8667855805258724e-05, weight decay:1.2866325687493887e-07
# val acc:0.22 | lr:0.0010109735114704774, weight decay:7.640853152406824e-08
# val acc:0.08 | lr:0.00040981053754531786, weight decay:7.344338251049737e-08
# val acc:0.5 | lr:0.0035663055555439443, weight decay:2.1126032339989496e-08
# val acc:0.06 | lr:5.0614912880828635e-05, weight decay:5.013500014561752e-07
# val acc:0.09 | lr:6.189498571117661e-06, weight decay:1.0635108348288935e-08
# val acc:0.13 | lr:7.830129320534264e-05, weight decay:4.324602702547112e-07
# val acc:0.03 | lr:4.077036654617978e-06, weight decay:6.935500746063779e-08
# val acc:0.11 | lr:2.310436814522791e-06, weight decay:1.73887553323924e-06
# val acc:0.12 | lr:0.00034486469504663755, weight decay:4.842723801307572e-07
# val acc:0.09 | lr:0.00035575004802802215, weight decay:8.080620439620334e-08
# val acc:0.09 | lr:1.6496798053571634e-05, weight decay:1.2343032623711027e-08
# val acc:0.25 | lr:0.0009440063397665222, weight decay:8.416921586603903e-05
# val acc:0.09 | lr:0.00010996975683496081, weight decay:6.618720865659158e-07
# val acc:0.11 | lr:1.7240165741210466e-06, weight decay:4.6205282438536015e-08
# val acc:0.1 | lr:0.00040391244380613147, weight decay:1.5600584233895496e-07
# val acc:0.13 | lr:4.3691275888267735e-06, weight decay:7.1182920380917195e-06
# val acc:0.14 | lr:6.309916077346186e-05, weight decay:3.468701860785869e-05
# val acc:0.12 | lr:2.637178959352432e-05, weight decay:2.4177676086951593e-05
# val acc:0.1 | lr:0.00029756670728982976, weight decay:4.415378375623447e-07
# val acc:0.18 | lr:0.0006786086365575783, weight decay:4.242424426261242e-06
# val acc:0.12 | lr:1.1161642143804336e-05, weight decay:1.3487666844153616e-06
# val acc:0.07 | lr:1.7354947652665514e-05, weight decay:1.804957458285936e-05
# val acc:0.13 | lr:3.637134166561375e-05, weight decay:2.823526488724765e-06
# val acc:0.59 | lr:0.004326989211514378, weight decay:7.156901090198418e-06
# val acc:0.27 | lr:0.0014366714071492152, weight decay:2.528404853191149e-08
# val acc:0.11 | lr:6.715948421557649e-05, weight decay:1.7016324194879973e-08
# val acc:0.14 | lr:0.00019155409739305174, weight decay:7.674930720975653e-05
# val acc:0.09 | lr:8.750548367127947e-06, weight decay:1.1623370527839353e-07
# val acc:0.03 | lr:3.4231758492562e-06, weight decay:3.713548323879029e-06
# val acc:0.11 | lr:1.240311161464373e-05, weight decay:6.119717985071705e-08
# val acc:0.07 | lr:1.7045493969305378e-05, weight decay:4.116267924472296e-07
# val acc:0.07 | lr:4.031904426450081e-05, weight decay:1.8027745630232302e-06
# val acc:0.64 | lr:0.00455707446572658, weight decay:1.4873750844538344e-08
# val acc:0.45 | lr:0.0020096051418538622, weight decay:7.601495729966185e-06
# val acc:0.06 | lr:1.5056753499831766e-06, weight decay:1.0376002472506895e-06
# val acc:0.01 | lr:2.9633618798667305e-05, weight decay:3.405557548340718e-06
# val acc:0.16 | lr:0.0003002990912274995, weight decay:2.8577645597270848e-05
# val acc:0.13 | lr:1.1007385019084089e-06, weight decay:2.4458780772697513e-06
# val acc:0.74 | lr:0.008373924316961882, weight decay:3.7832044690916386e-07
# val acc:0.12 | lr:1.7527339490139555e-06, weight decay:7.026404310972549e-07
# val acc:0.27 | lr:0.0016534782942794269, weight decay:9.060098519364018e-07
# val acc:0.24 | lr:0.001359018121169281, weight decay:4.766439855248818e-05
# val acc:0.13 | lr:0.00018105850423219116, weight decay:4.0788236970259555e-08
# val acc:0.5 | lr:0.0037464540953480105, weight decay:1.0194204923806702e-07
# val acc:0.21 | lr:0.0003033137755308962, weight decay:2.7063207180587847e-06
# val acc:0.13 | lr:6.1012418227454724e-06, weight decay:1.424934159530258e-08
# val acc:0.61 | lr:0.005116639979182621, weight decay:4.877312315599893e-07
# val acc:0.69 | lr:0.007425065612141739, weight decay:9.514632944806985e-06
# val acc:0.07 | lr:6.843733732236654e-05, weight decay:5.043049529640539e-05
# val acc:0.14 | lr:1.1660238302661149e-06, weight decay:1.2843845991878352e-07
# val acc:0.13 | lr:4.8102244987903095e-06, weight decay:1.3268998769590662e-05
# val acc:0.13 | lr:5.148663465615754e-06, weight decay:2.3132758016680033e-07
# val acc:0.13 | lr:4.950285564621348e-06, weight decay:1.0212960597606844e-06
# val acc:0.19 | lr:0.0010706840861507954, weight decay:9.91720479874543e-08
# val acc:0.29 | lr:0.0009929955041281138, weight decay:8.000301589090481e-08
# val acc:0.1 | lr:5.9721795107687135e-06, weight decay:7.922728360452911e-05
# val acc:0.43 | lr:0.002714354638863035, weight decay:4.4194595916945663e-07
# val acc:0.19 | lr:0.0012052731154969982, weight decay:6.14327049279088e-08
# val acc:0.08 | lr:2.9888451739422114e-05, weight decay:7.024837804844876e-05
# val acc:0.08 | lr:9.501258227772992e-06, weight decay:7.3928971472769754e-06
# val acc:0.04 | lr:8.637507039211914e-06, weight decay:1.189022954906338e-05
# val acc:0.38 | lr:0.0032543126548124236, weight decay:3.301018960835974e-08
# val acc:0.06 | lr:2.1017491986170366e-05, weight decay:2.656911575997364e-07
# val acc:0.06 | lr:2.854537500039767e-05, weight decay:1.7137696256881747e-08
# val acc:0.17 | lr:0.0012580828580773793, weight decay:3.7025139243339255e-07
# val acc:0.09 | lr:5.973676321867716e-06, weight decay:9.522042484965463e-07
# val acc:0.11 | lr:0.00022827822248828664, weight decay:2.2920701908096493e-08
# val acc:0.22 | lr:0.0009940300350491373, weight decay:1.0400483479005077e-08
# val acc:0.05 | lr:6.211311849615179e-06, weight decay:2.4286165773897627e-08
# val acc:0.09 | lr:1.203139407280225e-06, weight decay:1.0838296591573531e-06
# val acc:0.08 | lr:1.984368625554914e-06, weight decay:7.993305997492979e-07
# val acc:0.25 | lr:0.0016531151292681777, weight decay:1.742101811114521e-07
# val acc:0.16 | lr:0.000608612263517583, weight decay:3.502384686448573e-08
# val acc:0.12 | lr:9.065099661631157e-05, weight decay:1.6426475706651878e-06
# val acc:0.08 | lr:9.866562017798289e-06, weight decay:4.274366779287145e-06
# val acc:0.08 | lr:0.00018152802450423355, weight decay:3.512259864828718e-08
# val acc:0.11 | lr:0.00041911809790485686, weight decay:5.75883223908611e-06
# val acc:0.76 | lr:0.007229378508090226, weight decay:1.1007616688888732e-06
# val acc:0.11 | lr:2.8458229889440418e-05, weight decay:5.1909030037211746e-06
# val acc:0.04 | lr:6.009018293552297e-05, weight decay:8.047218061893574e-06
# val acc:0.7 | lr:0.005226565145414759, weight decay:3.8088814688648765e-07
# val acc:0.07 | lr:2.8572208558915526e-05, weight decay:5.194148291699505e-06
# val acc:0.1 | lr:2.4499487857977783e-06, weight decay:1.5834444869210945e-07
# =========== Hyper-Parameter Optimization Result ===========
# Best-1(val acc:0.76) | lr:0.007229378508090226, weight decay:1.1007616688888732e-06
# Best-2(val acc:0.74) | lr:0.008373924316961882, weight decay:3.7832044690916386e-07
# Best-3(val acc:0.7) | lr:0.005226565145414759, weight decay:3.8088814688648765e-07
# Best-4(val acc:0.69) | lr:0.007425065612141739, weight decay:9.514632944806985e-06
# Best-5(val acc:0.64) | lr:0.00455707446572658, weight decay:1.4873750844538344e-08
# Best-6(val acc:0.61) | lr:0.005116639979182621, weight decay:4.877312315599893e-07
# Best-7(val acc:0.6) | lr:0.0038396010559483564, weight decay:6.403676508719336e-07
# Best-8(val acc:0.59) | lr:0.004326989211514378, weight decay:7.156901090198418e-06
# Best-9(val acc:0.51) | lr:0.0041229437581514665, weight decay:6.96289016818388e-07
# Best-10(val acc:0.5) | lr:0.0037464540953480105, weight decay:1.0194204923806702e-07
# Best-11(val acc:0.5) | lr:0.0035663055555439443, weight decay:2.1126032339989496e-08
# Best-12(val acc:0.47) | lr:0.002375569122031199, weight decay:1.519221345384572e-08
# Best-13(val acc:0.45) | lr:0.0020096051418538622, weight decay:7.601495729966185e-06
# Best-14(val acc:0.44) | lr:0.002719917652844227, weight decay:4.556238875731326e-08
# Best-15(val acc:0.43) | lr:0.002714354638863035, weight decay:4.4194595916945663e-07
# Best-16(val acc:0.38) | lr:0.0032543126548124236, weight decay:3.301018960835974e-08
# Best-17(val acc:0.29) | lr:0.0009929955041281138, weight decay:8.000301589090481e-08
# Best-18(val acc:0.27) | lr:0.0016534782942794269, weight decay:9.060098519364018e-07
# Best-19(val acc:0.27) | lr:0.0014366714071492152, weight decay:2.528404853191149e-08
# Best-20(val acc:0.26) | lr:0.0013797097384103904, weight decay:4.0760743664319584e-07

# %% [markdown]
# # CNN

# %%
# coding: utf-8
import numpy as np
import matplotlib.pyplot as plt
from simple_convnet import SimpleConvNet

def filter_show(filters, nx=8, margin=3, scale=10):
    """
    c.f. https://gist.github.com/aidiary/07d530d5e08011832b12#file-draw_weight-py
    """
    FN, C, FH, FW = filters.shape
    ny = int(np.ceil(FN / nx))

    fig = plt.figure()
    fig.subplots_adjust(left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)

    for i in range(FN):
        ax = fig.add_subplot(ny, nx, i+1, xticks=[], yticks=[])
        ax.imshow(filters[i, 0], cmap=plt.cm.gray_r, interpolation='nearest')
    plt.show()


network = SimpleConvNet()
# ランダム初期化後の重み
filter_show(network.params['W1'])

# 学習後の重み
network.load_params("params.pkl")
filter_show(network.params['W1'])
